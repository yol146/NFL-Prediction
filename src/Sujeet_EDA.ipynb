# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = pd.read_csv("pre-impute data.csv")
temp
# Out:
#         Tm                 Date  Home  Opp  Week  G#  Day  Tm_1stD  \
# 0      NOR  2013-11-10 08:30:00     1  DAL    10   9  Sun       40
# 1      DEN  2013-12-08 04:05:00     1  TEN    14  13  Sun       39
# 2      HOU  2012-11-18 01:03:00     1  JAX    11  10  Sun       39
# 3      DET  2012-09-23 01:03:00     0  TEN     3   3  Sun       36
# 4      KAN  2004-10-24 01:00:00     1  ATL     7   6  Sun       36
# ...    ...                  ...   ...  ...   ...  ..  ...      ...
# 11460  NYJ  2022-01-09 01:00:00     0  BUF    18  17  Sun        4
# 11461  HOU  2002-12-08 01:01:00     0  PIT    14  13  Sun        3
# 11462  MIN  2006-12-21 08:05:00     0  GNB    16  15  Thu        3
# 11463  OAK  2008-11-02 04:15:00     1  ATL     9   8  Sun        3
# 11464  CLE  2000-12-03 04:16:00     0  JAX    14  14  Sun        2
#
#        Tm_Rsh1stD  Tm_Pass1stD  ...  Tm_RshTD  Tm_PassCmp%  Tm_PassYds  \
# 0              15           20  ...       3.0         82.9       383.0
# ...

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15, 7)

sns.heatmap(temp.isnull(), cbar=False, cmap="YlGnBu").set(title="Missing Data")

plt.savefig("missingdata.png")

# %%
train = pd.read_csv("final_data/train.csv")

# %%
corr = train.iloc[:,7:].drop(columns=["training"]).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_d80db_row0_col0,#T_d80db_row1_col1,#T_d80db_row2_col2,#T_d80db_row3_col3,#T_d80db_row4_col4,#T_d80db_row5_col5,#T_d80db_row6_col6,#T_d80db_row7_col7,#T_d80db_row8_col8,#T_d80db_row9_col9,#T_d80db_row10_col10,#T_d80db_row11_col11,#T_d80db_row12_col12,#T_d80db_row13_col13,#T_d80db_row14_col14,#T_d80db_row15_col15,#T_d80db_row16_col16,#T_d80db_row17_col17,#T_d80db_row18_col18,#T_d80db_row19_col19,#T_d80db_row20_col20,#T_d80db_row21_col21,#T_d80db_row22_col22,#T_d80db_row23_col23,#T_d80db_row24_col24,#T_d80db_row25_col25,#T_d80db_row26_col26,#T_d80db_row27_col27,#T_d80db_row28_col28,#T_d80db_row29_col29,#T_d80db_row30_col30,#T_d80db_row31_col31{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_d80db_row0_col1,#T_d80db_row17_col12{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_d80db_row0_col2{
#             background-color:  #f18f71;
#             color:  #000000;
# ...

# %%
df = pd.read_csv("data/final_data.csv")
df = df.rename(columns={"Opp_RshY/A": "Opp_RshYA", "Tm_RshY/A": "Tm_RshYA"})

# %%
df
# Out:
#         Tm                 Date  Home  Opp  Week  G#  Day  Tm_1stD  \
# 0      NOR  2013-11-10 08:30:00     1  DAL    10   9  Sun       40
# 1      DEN  2013-12-08 04:05:00     1  TEN    14  13  Sun       39
# 2      HOU  2012-11-18 01:03:00     1  JAX    11  10  Sun       39
# 3      DET  2012-09-23 01:03:00     0  TEN     3   3  Sun       36
# 4      KAN  2020-11-22 08:20:00     0  LVR    11  10  Sun       36
# ...    ...                  ...   ...  ...   ...  ..  ...      ...
# 11143  TAM  2009-09-27 01:00:00     1  NYG     3   3  Sun        5
# 11144  NYJ  2022-01-09 01:00:00     0  BUF    18  17  Sun        4
# 11145  HOU  2002-12-08 01:01:00     0  PIT    14  13  Sun        3
# 11146  MIN  2006-12-21 08:05:00     0  GNB    16  15  Thu        3
# 11147  OAK  2008-11-02 04:15:00     1  ATL     9   8  Sun        3
#
#        Tm_Rsh1stD  Tm_Pass1stD  ...  Tm_PassCmp%  Tm_PassYds  Tm_PassTD  \
# 0              15           20  ...         82.9       383.0        4.0
# ...

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(10,5)

df.Spread.hist(bins=50).set(title="Spread")
plt.vlines([df.Spread.describe()["25%"] - 1.5*(df.Spread.describe()["75%"] - df.Spread.describe()["25%"]), df.Spread.describe()["75%"] + 1.5*(df.Spread.describe()["75%"] - df.Spread.describe()["25%"])], 1, 1200, color="red")
plt.savefig("plots/Spread_Outliers.png")

print()

# %%
g = sns.scatterplot(data=df, x="Spread", y="Tm_QBRating", hue="Home", alpha=0.5)
g.set(title="Tm_QBRating vs. Spread")
g.figure.set_size_inches(10,7)
plt.savefig("plots/scatter/Tm_QBRating vs. Spread.png")

# %%
df
# Out:
#         Tm                 Date  Home  Opp  Week  G#  Day  Tm_1stD  \
# 0      NOR  2013-11-10 08:30:00     1  DAL    10   9  Sun       40
# 1      DEN  2013-12-08 04:05:00     1  TEN    14  13  Sun       39
# 2      HOU  2012-11-18 01:03:00     1  JAX    11  10  Sun       39
# 3      DET  2012-09-23 01:03:00     0  TEN     3   3  Sun       36
# 4      KAN  2004-10-24 01:00:00     1  ATL     7   6  Sun       36
# ...    ...                  ...   ...  ...   ...  ..  ...      ...
# 11460  NYJ  2022-01-09 01:00:00     0  BUF    18  17  Sun        4
# 11461  HOU  2002-12-08 01:01:00     0  PIT    14  13  Sun        3
# 11462  MIN  2006-12-21 08:05:00     0  GNB    16  15  Thu        3
# 11463  OAK  2008-11-02 04:15:00     1  ATL     9   8  Sun        3
# 11464  CLE  2000-12-03 04:16:00     0  JAX    14  14  Sun        2
#
#        Tm_Rsh1stD  Tm_Pass1stD  ...  Tm_RshTD  Tm_PassCmp%  Tm_PassYds  \
# 0              15           20  ...       3.0         82.9       383.0
# ...

# %%
print(df.columns)
xcols_scatter = ['Tm_1stD', 'Tm_Rsh1stD', 'Tm_Pass1stD', 'Tm_3D%', 'Comb_Pen',
 'Comb_Yds', 'Opp_1stD', 'Opp_Rush1stD', 'Opp_Pass1stD',
 'Opp_PassCmp%', 'Opp_PassYds', 'Opp_SkYds', 'Opp_QBRating', 'Opp_RshYA', 
 'Tm_Temperature', 'Tm_RshYA', 'Tm_RshTD', 'Tm_PassCmp%', 'Tm_PassYds', 'Tm_SkYds', 'Tm_QBRating', 'Tm_TOP',
 'Opp_Int', 'Opp_PassTD', 'Opp_Pen1stD', 'Opp_RshTD', 'Opp_Rush1stD', 'Opp_Sk', 'Tm_INT', 'Tm_PassTD', 'Tm_Pen1stD', 'Tm_Sk']

for col in xcols_scatter:
    sns.scatterplot(data=df, x=col, y="Spread").set(title=col + "_vs_Spread")
    plt.savefig("plots/scatter/" + col + "_vs_Spread.png")
    plt.show()
    
    sns.displot(data=df, x=col).set(title=col)
    plt.savefig("plots/histograms/" + col + ".png")
    plt.show()
# Out:
# Index(['Tm', 'Date', 'Home', 'Opp', 'Week', 'G#', 'Day', 'Tm_1stD',
#        'Tm_Rsh1stD', 'Tm_Pass1stD', 'Tm_Pen1stD', 'Tm_3D%', 'Comb_Pen',
#        'Comb_Yds', 'Opp_1stD', 'Opp_Rush1stD', 'Opp_Pass1stD', 'Opp_Pen1stD',
#        'Opp_PassCmp%', 'Opp_PassYds', 'Opp_PassTD', 'Opp_Int', 'Opp_Sk',
#        'Opp_SkYds', 'Opp_QBRating', 'Opp_RshYA', 'Opp_RshTD', 'Tm_Temperature',
#        'Tm_RshYA', 'Tm_RshTD', 'Tm_PassCmp%', 'Tm_PassYds', 'Tm_PassTD',
#        'Tm_INT', 'Tm_Sk', 'Tm_SkYds', 'Tm_QBRating', 'Tm_TOP', 'Spread'],
#       dtype='object')

# %%
df = df.loc[~df["Tm_QBRating"].isnull()]

# %%
x_cols = ["Tm_QBRating", "Opp_QBRating", "Home"]

import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

sf = StandardScaler()
sf.fit(df[x_cols])

X = sm.add_constant(sf.transform(df[x_cols]))
y = df.Spread

model = sm.OLS(y, X)
results = model.fit()

results.params
# Out:
# const   -0.006449
# x1       7.887095
# x2      -7.993100
# x3       1.215045
# dtype: float64

# %%
df.Opp_QBRating.std()
# Out:
# 27.84495644870859

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Spread   R-squared:                       0.614
# Model:                            OLS   Adj. R-squared:                  0.614
# Method:                 Least Squares   F-statistic:                     5927.
# Date:                Fri, 04 Feb 2022   Prob (F-statistic):               0.00
# Time:                        13:53:39   Log-Likelihood:                -40692.
# No. Observations:               11164   AIC:                         8.139e+04
# Df Residuals:                   11160   BIC:                         8.142e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0064      0.088     -0.074      0.941      -0.178       0.165
# ...

# %%
y_train = np.array(train["Spread"])

# %%
abc =1/y_train
# Out:
# /Users/dino_liu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
efg=1/np.array([1,2,4,0])
# Out:
# /Users/dino_liu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
efg[efg == np.inf] = 0

# %%
efg
# Out:
# array([1.  , 0.5 , 0.25, 0.  ])

# %%
pd.Series(np.log(y_train)).fillna(0).replace(np.log(0),0)
# Out:
# /Users/dino_liu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /Users/dino_liu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# 0        3.465736
# 1        3.135494
# 2        1.791759
# 3        0.000000
# 4        0.693147
#            ...
# 10092    0.000000
# 10093    0.000000
# 10094    2.890372
# 10095    0.000000
# 10096    0.000000
# Length: 10097, dtype: float64

# %%
(pd.Series(np.log(y_train)).fillna(0) == np.log(0)).mean()
# Out:
# /Users/dino_liu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /Users/dino_liu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# 0.0019807863721897595

# %%
np.log(0)
# Out:
# /Users/dino_liu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# -inf

# %%
(train["Tm_QBRating"]-train["Opp_QBRating"]).hist(bins=50)
